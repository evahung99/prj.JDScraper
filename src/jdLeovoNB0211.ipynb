# %% [markdown]
# ## 使用python獲取京東商品數據以及好評度爬蟲傻瓜式入門（二）
# 本章內容主要解決，如何多頁獲取手機&電腦數據，獲取評價以及好評率等信息
# - https://ek21.com/news/tech/58573/

# %% [markdown]
# ## 如何獲取評論信息？
#
# 首先我们来到京东随便搜索一个商品，并且进入商品具体页面，检测network, 搜索 comment, 不难发现这个页面获取了评论有关的json数据：
#
# > https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv4645&productId=100005171461&score=0&sortType=5&page=0&pageSize=10&isShadowSku=0&fold=1

# %%
#!/usr/bin/env python
# -*- coding:utf-8 -*-
import re, requests, csv, codecs
from requests.exceptions import RequestException
from bs4 import BeautifulSoup

# %%
# 1、要取所有的电脑数据，首先得获得所有电脑的网页源码，以及url地址如下：
def download(url, headers, num_retries=3):
    print("download", url)
    try:
        response = requests.get(url, headers=headers)
        print(response.status_code)
        # 如果相应的状态码为：200 那么return 返回网站源码，如果访问非200则调用重试
        if response.status_code == 200:
            return response.content
        return None
    except RequestException as e:
        print(e.response)
        html = ""
        if hasattr(e.response, 'status_code'):
            code = e.response.status_code
            print('error code', code)
            if num_retries > 0 and 500 <= code < 600:
                html = download(url, headers, num_retries - 1)
        else:
            code = None
    return html

# %%
def get_json(url):
    data = requests.get(url).json()
    print(data)
    result = data['CommentsCount']
    for i in result:
        return i["CommentCountStr"], i["GoodRateShow"]

# %%
def find_Computer(url, headers):
    r = download(url, headers=headers)
    # print(r)
    page = BeautifulSoup(r, "lxml")
    #print(page.prettify())

    all_items = page.find_all('li', attrs={'class':'gl-item'})
    
    with open("Computer.csv", 'w', newline='', encoding='utf-8-sig') as f:
        writer = csv.writer(f)
        fields = ('ID', 'NAME', 'PRICE', 'Comment#', 'Good Ratio')
        writer.writerow(fields)
        # 4、接下来通过for循环将找到的所有电脑源码进行循环。
        for all in all_items:
            Computer_id = all["data-sku"]
            Computer_name = all.find('div', attrs={'class': 'p-name p-name-type-2'}).find('em').text
            _price = all.find('div', attrs={'class': 'p-price'}).find('strong')
            Computer_price = _price.get('data-price', _price.find('i').text)

            # 取每台電腦的Json數據(包含 評價等等信息)
            Comment = f"https://club.jd.com/comment/productCommentSummaries.action?referenceIds={Computer_id}"
            comment_count, good_rate = get_json(Comment)
            
            print(f"ID：{Computer_id}")
            print(f"Name：{Computer_name}")
            print(f"Price：{Computer_price}元")
            print(f"Comment#：", comment_count)
            print(f"Good Ratio：{good_rate}\n")
            
            row = []
            row.append(Computer_id)
            row.append(Computer_name)
            row.append(str(Computer_price) + "元")
            row.append(comment_count)
            row.append(good_rate)
            writer.writerow(row)

# %%
def main():
    headers = {
    'User-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36",
    "referer": "https://search.jd.com"
    }

    URL="https://search.jd.com/Search?keyword=lenovo&enc=utf-8&wq=lenovo&pvid=271f6c114446474f91249bbd788b7090"
    find_Computer(URL, headers=headers)

if __name__ == '__main__':
    main()
# Out:
# download https://search.jd.com/Search?keyword=lenovo&enc=utf-8&wq=lenovo&pvid=271f6c114446474f91249bbd788b7090
# 200
# {'CommentsCount': [{'SkuId': 100005171461, 'ProductId': 100005171461, 'ShowCount': 15070, 'ShowCountStr': '1.5万+', 'CommentCountStr': '17万+', 'CommentCount': 175145, 'AverageScore': 5, 'DefaultGoodCountStr': '13万+', 'DefaultGoodCount': 132444, 'GoodCountStr': '3.9万+', 'GoodCount': 39989, 'AfterCount': 2721, 'OneYear': 0, 'AfterCountStr': '2700+', 'VideoCount': 2937, 'VideoCountStr': '2900+', 'GoodRate': 0.93, 'GoodRateShow': 93, 'GoodRateStyle': 139, 'GeneralCountStr': '1100+', 'GeneralCount': 1174, 'GeneralRate': 0.027, 'GeneralRateShow': 3, 'GeneralRateStyle': 4, 'PoorCountStr': '1500+', 'PoorCount': 1538, 'SensitiveBook': 0, 'PoorRate': 0.043, 'PoorRateShow': 4, 'PoorRateStyle': 7}]}
# ID：100005171461
# Name：联想(Lenovo)小新Pro13.3英寸全面屏超轻薄笔记本电脑(标压锐龙R5-3550H 16G 512G 2.5K QHD 100%sRGB)银
# Price：4499.00元
# Comment#： 17万+
# Good Ratio：93
#
# {'CommentsCount': [{'SkuId': 100004286189, 'ProductId': 100004286189, 'ShowCount': 15070, 'ShowCountStr': '1.5万+', 'CommentCountStr': '17万+', 'CommentCount': 175140, 'AverageScore': 5, 'DefaultGoodCountStr': '13万+', 'DefaultGoodCount': 132445, 'GoodCountStr': '3.9万+', 'GoodCount': 39983, 'AfterCount': 2721, 'OneYear': 0, 'AfterCountStr': '2700+', 'VideoCount': 2937, 'VideoCountStr': '2900+', 'GoodRate': 0.93, 'GoodRateShow': 93, 'GoodRateStyle': 139, 'GeneralCountStr': '1100+', 'GeneralCount': 1174, 'GeneralRate': 0.027, 'GeneralRateShow': 3, 'GeneralRateStyle': 4, 'PoorCountStr': '1500+', 'PoorCount': 1538, 'SensitiveBook': 0, 'PoorRate': 0.043, 'PoorRateShow': 4, 'PoorRateStyle': 7}]}
# ID：100004286189
# Name：京品电脑联想(Lenovo)小新Air14英寸 AMD锐龙版(全新12nm)轻薄笔记本电脑(R5-3500U 12G 512G PCIE IPS)轻奢灰
# Price：4299.00元
# Comment#： 17万+
# Good Ratio：93
#
# {'CommentsCount': [{'SkuId': 100003688077, 'ProductId': 100003688077, 'ShowCount': 25705, 'ShowCountStr': '2.5万+', 'CommentCountStr': '33万+', 'CommentCount': 336678, 'AverageScore': 5, 'DefaultGoodCountStr': '24万+', 'DefaultGoodCount': 243077, 'GoodCountStr': '9.1万+', 'GoodCount': 91752, 'AfterCount': 4407, 'OneYear': 0, 'AfterCountStr': '4400+', 'VideoCount': 3354, 'VideoCountStr': '3300+', 'GoodRate': 0.96, 'GoodRateShow': 96, 'GoodRateStyle': 144, 'GeneralCountStr': '1600+', 'GeneralCount': 1671, 'GeneralRate': 0.017, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '2100+', 'PoorCount': 2131, 'SensitiveBook': 0, 'PoorRate': 0.023, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：100003688077
# Name：京品电脑联想(Lenovo)拯救者Y7000P 2019英特尔酷睿i715.6英寸游戏笔记本电脑(i7-9750H 16G 1T SSD GTX1660Ti 144Hz)
# Price：9299.00元
# Comment#： 33万+
# Good Ratio：96
#
# {'CommentsCount': [{'SkuId': 100004841883, 'ProductId': 100004841883, 'ShowCount': 11879, 'ShowCountStr': '1.1万+', 'CommentCountStr': '11万+', 'CommentCount': 116679, 'AverageScore': 5, 'DefaultGoodCountStr': '8.7万+', 'DefaultGoodCount': 87962, 'GoodCountStr': '2.7万+', 'GoodCount': 27918, 'AfterCount': 1549, 'OneYear': 0, 'AfterCountStr': '1500+', 'VideoCount': 1945, 'VideoCountStr': '1900+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '700+', 'GeneralCount': 726, 'GeneralRate': 0.024, 'GeneralRateShow': 2, 'GeneralRateStyle': 4, 'PoorCountStr': '700+', 'PoorCount': 787, 'SensitiveBook': 0, 'PoorRate': 0.036, 'PoorRateShow': 4, 'PoorRateStyle': 5}]}
# ID：100004841883
# Name：联想(Lenovo)小新Pro13.3英寸英特尔酷睿i5全面屏超轻薄笔记本电脑(I5-10210U 16G 512G MX250 2.5K QHD)银
# Price：6299.00元
# Comment#： 11万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 60220113212, 'ProductId': 60220113212, 'ShowCount': 757, 'ShowCountStr': '700+', 'CommentCountStr': '6200+', 'CommentCount': 6257, 'AverageScore': 5, 'DefaultGoodCountStr': '4700+', 'DefaultGoodCount': 4739, 'GoodCountStr': '1400+', 'GoodCount': 1441, 'AfterCount': 80, 'OneYear': 0, 'AfterCountStr': '80+', 'VideoCount': 79, 'VideoCountStr': '70+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '20+', 'GeneralCount': 28, 'GeneralRate': 0.018, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '40+', 'PoorCount': 49, 'SensitiveBook': 0, 'PoorRate': 0.042, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：60220113212
# Name：联想（Lenovo）小新Pro13.3英寸轻薄笔记本电脑锐龙R5-3550H 16G 512G固态 高效办公套装
# Price：4766.00元
# Comment#： 6200+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100010756268, 'ProductId': 100010756268, 'ShowCount': 1971, 'ShowCountStr': '1900+', 'CommentCountStr': '1.6万+', 'CommentCount': 16343, 'AverageScore': 5, 'DefaultGoodCountStr': '1.2万+', 'DefaultGoodCount': 12174, 'GoodCountStr': '3900+', 'GoodCount': 3939, 'AfterCount': 195, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 217, 'VideoCountStr': '200+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '90+', 'GeneralCount': 92, 'GeneralRate': 0.022, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '100+', 'PoorCount': 138, 'SensitiveBook': 0, 'PoorRate': 0.038, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：100010756268
# Name：联想(Lenovo)YOGAS740英特尔酷睿i5 14.0英寸超轻薄笔记本电脑移动超能版(i5-1035G1 8G 512G MX250)深空灰
# Price：5499.00元
# Comment#： 1.6万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100004498316, 'ProductId': 100004498316, 'ShowCount': 6609, 'ShowCountStr': '6600+', 'CommentCountStr': '16万+', 'CommentCount': 165550, 'AverageScore': 5, 'DefaultGoodCountStr': '12万+', 'DefaultGoodCount': 125293, 'GoodCountStr': '7.3万+', 'GoodCount': 73916, 'AfterCount': 1649, 'OneYear': 0, 'AfterCountStr': '1600+', 'VideoCount': 1041, 'VideoCountStr': '1000+', 'GoodRate': 0.96, 'GoodRateShow': 96, 'GoodRateStyle': 144, 'GeneralCountStr': '900+', 'GeneralCount': 949, 'GeneralRate': 0.012, 'GeneralRateShow': 1, 'GeneralRateStyle': 2, 'PoorCountStr': '1300+', 'PoorCount': 1369, 'SensitiveBook': 0, 'PoorRate': 0.028, 'PoorRateShow': 3, 'PoorRateStyle': 4}]}
# ID：100004498316
# Name：联想(Lenovo)小新青春版  英特尔酷睿i7 14英寸 轻薄笔记本电脑(I7-8565U 8G 1T+128G FHD 2G独显)无畏黑
# Price：5799.00元
# Comment#： 16万+
# Good Ratio：96
#
# {'CommentsCount': [{'SkuId': 100010370676, 'ProductId': 100010370676, 'ShowCount': 1202, 'ShowCountStr': '1200+', 'CommentCountStr': '2.1万+', 'CommentCount': 21999, 'AverageScore': 5, 'DefaultGoodCountStr': '1.7万+', 'DefaultGoodCount': 17268, 'GoodCountStr': '4500+', 'GoodCount': 4504, 'AfterCount': 238, 'OneYear': 0, 'AfterCountStr': '200+', 'VideoCount': 109, 'VideoCountStr': '100+', 'GoodRate': 0.95, 'GoodRateShow': 95, 'GoodRateStyle': 142, 'GeneralCountStr': '100+', 'GeneralCount': 110, 'GeneralRate': 0.023, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '100+', 'PoorCount': 117, 'SensitiveBook': 0, 'PoorRate': 0.027, 'PoorRateShow': 3, 'PoorRateStyle': 5}]}
# ID：100010370676
# Name：联想（Lenovo）威6 2020款 英特尔酷睿 i5 14英寸窄边框轻薄笔记本电脑(i5-1035G1 8G 512G PCIE 2G独显 全功能Type-C)相思灰
# Price：4499.00元
# Comment#： 2.1万+
# Good Ratio：95
#
# {'CommentsCount': [{'SkuId': 43693541859, 'ProductId': 43693541859, 'ShowCount': 288, 'ShowCountStr': '200+', 'CommentCountStr': '5100+', 'CommentCount': 5159, 'AverageScore': 5, 'DefaultGoodCountStr': '3900+', 'DefaultGoodCount': 3947, 'GoodCountStr': '1100+', 'GoodCount': 1173, 'AfterCount': 61, 'OneYear': 0, 'AfterCountStr': '60+', 'VideoCount': 54, 'VideoCountStr': '50+', 'GoodRate': 0.93, 'GoodRateShow': 93, 'GoodRateStyle': 139, 'GeneralCountStr': '40+', 'GeneralCount': 41, 'GeneralRate': 0.032, 'GeneralRateShow': 3, 'GeneralRateStyle': 5, 'PoorCountStr': '40+', 'PoorCount': 46, 'SensitiveBook': 0, 'PoorRate': 0.038, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：43693541859
# Name：联想（Lenovo）小新Air14英寸 轻薄笔记本电脑 灰色 锐龙 R7-2700U 8G 512G SSD
# Price：3799.00元
# Comment#： 5100+
# Good Ratio：93
#
# {'CommentsCount': [{'SkuId': 100007539116, 'ProductId': 100007539116, 'ShowCount': 11879, 'ShowCountStr': '1.1万+', 'CommentCountStr': '11万+', 'CommentCount': 116678, 'AverageScore': 5, 'DefaultGoodCountStr': '8.7万+', 'DefaultGoodCount': 87962, 'GoodCountStr': '2.7万+', 'GoodCount': 27917, 'AfterCount': 1549, 'OneYear': 0, 'AfterCountStr': '1500+', 'VideoCount': 1945, 'VideoCountStr': '1900+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '700+', 'GeneralCount': 726, 'GeneralRate': 0.024, 'GeneralRateShow': 2, 'GeneralRateStyle': 4, 'PoorCountStr': '700+', 'PoorCount': 787, 'SensitiveBook': 0, 'PoorRate': 0.036, 'PoorRateShow': 4, 'PoorRateStyle': 5}]}
# ID：100007539116
# Name：联想(Lenovo)小新Air14英寸英特尔酷睿i5 超轻薄笔记本电脑(I5-10210U 12G 512G MX250 72％NTSC)轻奢灰
# Price：5499.00元
# Comment#： 11万+
# Good Ratio：94
# {'CommentsCount': [{'SkuId': 100003383325, 'ProductId': 100003383325, 'ShowCount': 2822, 'ShowCountStr': '2800+', 'CommentCountStr': '10万+', 'CommentCount': 107844, 'AverageScore': 5, 'DefaultGoodCountStr': '8.5万+', 'DefaultGoodCount': 85766, 'GoodCountStr': '3.7万+', 'GoodCount': 37018, 'AfterCount': 651, 'OneYear': 0, 'AfterCountStr': '600+', 'VideoCount': 374, 'VideoCountStr': '300+', 'GoodRate': 0.97, 'GoodRateShow': 97, 'GoodRateStyle': 145, 'GeneralCountStr': '200+', 'GeneralCount': 278, 'GeneralRate': 0.007, 'GeneralRateShow': 1, 'GeneralRateStyle': 1, 'PoorCountStr': '600+', 'PoorCount': 616, 'SensitiveBook': 0, 'PoorRate': 0.023, 'PoorRateShow': 2, 'PoorRateStyle': 4}]}
# ID：100003383325
# Name：联想(Lenovo)天逸510S 英特尔酷睿i3 个人商务台式机电脑整机(i3-9100 8G 1T WiFi  三年上门 Win10)21.5英寸
# Price：2899.00元
# Comment#： 10万+
# Good Ratio：97
#
# {'CommentsCount': [{'SkuId': 100008492048, 'ProductId': 100008492048, 'ShowCount': 11879, 'ShowCountStr': '1.1万+', 'CommentCountStr': '11万+', 'CommentCount': 116679, 'AverageScore': 5, 'DefaultGoodCountStr': '8.7万+', 'DefaultGoodCount': 87962, 'GoodCountStr': '2.7万+', 'GoodCount': 27918, 'AfterCount': 1549, 'OneYear': 0, 'AfterCountStr': '1500+', 'VideoCount': 1945, 'VideoCountStr': '1900+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '700+', 'GeneralCount': 726, 'GeneralRate': 0.024, 'GeneralRateShow': 2, 'GeneralRateStyle': 4, 'PoorCountStr': '700+', 'PoorCount': 787, 'SensitiveBook': 0, 'PoorRate': 0.036, 'PoorRateShow': 4, 'PoorRateStyle': 5}]}
# ID：100008492048
# Name：联想(Lenovo)小新Air15.6英寸 英特尔酷睿i7 超轻薄笔记本电脑(I7-10510U 12G 1TSSD MX250 72%NTSC )轻奢灰
# Price：6799.00元
# Comment#： 11万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100008535980, 'ProductId': 100008535980, 'ShowCount': 11879, 'ShowCountStr': '1.1万+', 'CommentCountStr': '11万+', 'CommentCount': 116679, 'AverageScore': 5, 'DefaultGoodCountStr': '8.7万+', 'DefaultGoodCount': 87962, 'GoodCountStr': '2.7万+', 'GoodCount': 27918, 'AfterCount': 1549, 'OneYear': 0, 'AfterCountStr': '1500+', 'VideoCount': 1945, 'VideoCountStr': '1900+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '700+', 'GeneralCount': 726, 'GeneralRate': 0.024, 'GeneralRateShow': 2, 'GeneralRateStyle': 4, 'PoorCountStr': '700+', 'PoorCount': 787, 'SensitiveBook': 0, 'PoorRate': 0.036, 'PoorRateShow': 4, 'PoorRateStyle': 5}]}
# ID：100008535980
# Name：京品电脑联想(Lenovo)小新Pro13.3英寸 英特尔酷睿i5全面屏超轻薄笔记本电脑(I5-10210U 8G 512G 2.5K QHD100%sRGB)银
# Price：5499.00元
# Comment#： 11万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100003052985, 'ProductId': 100003052985, 'ShowCount': 15070, 'ShowCountStr': '1.5万+', 'CommentCountStr': '17万+', 'CommentCount': 175139, 'AverageScore': 5, 'DefaultGoodCountStr': '13万+', 'DefaultGoodCount': 132444, 'GoodCountStr': '3.9万+', 'GoodCount': 39983, 'AfterCount': 2721, 'OneYear': 0, 'AfterCountStr': '2700+', 'VideoCount': 2937, 'VideoCountStr': '2900+', 'GoodRate': 0.93, 'GoodRateShow': 93, 'GoodRateStyle': 139, 'GeneralCountStr': '1100+', 'GeneralCount': 1174, 'GeneralRate': 0.027, 'GeneralRateShow': 3, 'GeneralRateStyle': 4, 'PoorCountStr': '1500+', 'PoorCount': 1538, 'SensitiveBook': 0, 'PoorRate': 0.043, 'PoorRateShow': 4, 'PoorRateStyle': 7}]}
# ID：100003052985
# Name：联想(Lenovo)小新14英寸 AMD锐龙版R5（全新12nm）轻薄笔记本电脑(R5-3500U 8G 1TB+256G PCIE IPS)渣渣灰
# Price：3999.00元
# Comment#： 17万+
# Good Ratio：93
#
# {'CommentsCount': [{'SkuId': 100005769755, 'ProductId': 100005769755, 'ShowCount': 1971, 'ShowCountStr': '1900+', 'CommentCountStr': '1.6万+', 'CommentCount': 16342, 'AverageScore': 5, 'DefaultGoodCountStr': '1.2万+', 'DefaultGoodCount': 12173, 'GoodCountStr': '3900+', 'GoodCount': 3939, 'AfterCount': 195, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 217, 'VideoCountStr': '200+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '90+', 'GeneralCount': 92, 'GeneralRate': 0.022, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '100+', 'PoorCount': 138, 'SensitiveBook': 0, 'PoorRate': 0.038, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：100005769755
# Name：联想(Lenovo) LEGION Y9000X 15.6英寸高性能标压轻薄笔记本电脑(i7-9750H 32G 1TSSD FHD)深空灰
# Price：9499.00元
# Comment#： 1.6万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100004442453, 'ProductId': 100004442453, 'ShowCount': 1971, 'ShowCountStr': '1900+', 'CommentCountStr': '1.6万+', 'CommentCount': 16343, 'AverageScore': 5, 'DefaultGoodCountStr': '1.2万+', 'DefaultGoodCount': 12174, 'GoodCountStr': '3900+', 'GoodCount': 3939, 'AfterCount': 195, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 217, 'VideoCountStr': '200+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '90+', 'GeneralCount': 92, 'GeneralRate': 0.022, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '100+', 'PoorCount': 138, 'SensitiveBook': 0, 'PoorRate': 0.038, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：100004442453
# Name：京品电脑联想(Lenovo)YOGA C940 英特尔酷睿i7  14.0英寸超轻薄笔记本电脑(i7-1065G7 16G 1T SSD UHD)深空灰
# Price：10999.00元
# Comment#： 1.6万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 57773460022, 'ProductId': 57773460022, 'ShowCount': 1164, 'ShowCountStr': '1100+', 'CommentCountStr': '2.1万+', 'CommentCount': 21273, 'AverageScore': 5, 'DefaultGoodCountStr': '1.7万+', 'DefaultGoodCount': 17960, 'GoodCountStr': '3200+', 'GoodCount': 3257, 'AfterCount': 184, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 137, 'VideoCountStr': '100+', 'GoodRate': 0.98, 'GoodRateShow': 98, 'GoodRateStyle': 147, 'GeneralCountStr': '10+', 'GeneralCount': 12, 'GeneralRate': 0.003, 'GeneralRateShow': 0, 'GeneralRateStyle': 0, 'PoorCountStr': '40+', 'PoorCount': 44, 'SensitiveBook': 0, 'PoorRate': 0.017, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：57773460022
# Name：联想（Lenovo）小新Air14锐龙版R7笔记本电脑超薄本超级本学生用轻薄女生商务办公游戏超极本 定制丨锐龙7 16G内存 512G固态 荣耀银 2019
# Price：3999.00元
# Comment#： 2.1万+
# Good Ratio：98
#
# {'CommentsCount': [{'SkuId': 100005188049, 'ProductId': 100005188049, 'ShowCount': 1202, 'ShowCountStr': '1200+', 'CommentCountStr': '2.2万+', 'CommentCount': 22000, 'AverageScore': 5, 'DefaultGoodCountStr': '1.7万+', 'DefaultGoodCount': 17268, 'GoodCountStr': '4500+', 'GoodCount': 4505, 'AfterCount': 238, 'OneYear': 0, 'AfterCountStr': '200+', 'VideoCount': 109, 'VideoCountStr': '100+', 'GoodRate': 0.95, 'GoodRateShow': 95, 'GoodRateStyle': 142, 'GeneralCountStr': '100+', 'GeneralCount': 110, 'GeneralRate': 0.023, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '100+', 'PoorCount': 117, 'SensitiveBook': 0, 'PoorRate': 0.027, 'PoorRateShow': 3, 'PoorRateStyle': 5}]}
# ID：100005188049
# Name：联想（Lenovo）威6 2020款 英特尔酷睿 i5 14英寸窄边框轻薄笔记本电脑(i5-10210U 8G 512G PCIE 2G独显 FHD 全功能Type-C)相思灰
# Price：4599.00元
# Comment#： 2.2万+
# Good Ratio：95
#
# {'CommentsCount': [{'SkuId': 100006498814, 'ProductId': 100006498814, 'ShowCount': 887, 'ShowCountStr': '800+', 'CommentCountStr': '2.9万+', 'CommentCount': 29899, 'AverageScore': 5, 'DefaultGoodCountStr': '2.3万+', 'DefaultGoodCount': 23556, 'GoodCountStr': '6000+', 'GoodCount': 6042, 'AfterCount': 267, 'OneYear': 0, 'AfterCountStr': '200+', 'VideoCount': 102, 'VideoCountStr': '100+', 'GoodRate': 0.95, 'GoodRateShow': 95, 'GoodRateStyle': 142, 'GeneralCountStr': '90+', 'GeneralCount': 96, 'GeneralRate': 0.015, 'GeneralRateShow': 2, 'GeneralRateStyle': 2, 'PoorCountStr': '200+', 'PoorCount': 205, 'SensitiveBook': 0, 'PoorRate': 0.035, 'PoorRateShow': 3, 'PoorRateStyle': 6}]}
# ID：100006498814
# Name：京品电脑联想(Lenovo)AIO逸 英特尔酷睿i5 微边框一体机台式电脑23.8英寸(六核i5-9400T 8G 512G 2G独显 )黑
# Price：4769.00元
# Comment#： 2.9万+
# Good Ratio：95
#
# {'CommentsCount': [{'SkuId': 100010880906, 'ProductId': 100010880906, 'ShowCount': 157, 'ShowCountStr': '100+', 'CommentCountStr': '1500+', 'CommentCount': 1557, 'AverageScore': 5, 'DefaultGoodCountStr': '1100+', 'DefaultGoodCount': 1106, 'GoodCountStr': '400+', 'GoodCount': 428, 'AfterCount': 31, 'OneYear': 0, 'AfterCountStr': '30+', 'VideoCount': 8, 'VideoCountStr': '8', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '10+', 'GeneralCount': 13, 'GeneralRate': 0.038, 'GeneralRateShow': 4, 'GeneralRateStyle': 6, 'PoorCountStr': '10', 'PoorCount': 10, 'SensitiveBook': 0, 'PoorRate': 0.022, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：100010880906
# Name：联想(Lenovo) S550 14英寸 AMD锐龙版(全新12nm)轻薄笔记本电脑(R5-3500U 8G 512G PCIE IPS)太空灰
# Price：3799.00元
# Comment#： 1500+
# Good Ratio：94
# {'CommentsCount': [{'SkuId': 8577742, 'ProductId': 8577742, 'ShowCount': 528, 'ShowCountStr': '500+', 'CommentCountStr': '2.1万+', 'CommentCount': 21769, 'AverageScore': 5, 'DefaultGoodCountStr': '1.7万+', 'DefaultGoodCount': 17475, 'GoodCountStr': '1万+', 'GoodCount': 10777, 'AfterCount': 214, 'OneYear': 0, 'AfterCountStr': '200+', 'VideoCount': 70, 'VideoCountStr': '70+', 'GoodRate': 0.96, 'GoodRateShow': 96, 'GoodRateStyle': 144, 'GeneralCountStr': '100+', 'GeneralCount': 114, 'GeneralRate': 0.01, 'GeneralRateShow': 1, 'GeneralRateStyle': 2, 'PoorCountStr': '200+', 'PoorCount': 245, 'SensitiveBook': 0, 'PoorRate': 0.03, 'PoorRateShow': 3, 'PoorRateStyle': 4}]}
# ID：8577742
# Name：联想（Lenovo）AIO 520 致美一体机台式电脑23.8英寸（AMD A6-9500E 4G 1T WIFI 蓝牙 三年上门 Win10）银
# Price：2899.00元
# Comment#： 2.1万+
# Good Ratio：96
#
# {'CommentsCount': [{'SkuId': 57773460021, 'ProductId': 57773460021, 'ShowCount': 1164, 'ShowCountStr': '1100+', 'CommentCountStr': '2.1万+', 'CommentCount': 21274, 'AverageScore': 5, 'DefaultGoodCountStr': '1.7万+', 'DefaultGoodCount': 17960, 'GoodCountStr': '3200+', 'GoodCount': 3258, 'AfterCount': 184, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 137, 'VideoCountStr': '100+', 'GoodRate': 0.98, 'GoodRateShow': 98, 'GoodRateStyle': 147, 'GeneralCountStr': '10+', 'GeneralCount': 12, 'GeneralRate': 0.003, 'GeneralRateShow': 0, 'GeneralRateStyle': 0, 'PoorCountStr': '40+', 'PoorCount': 44, 'SensitiveBook': 0, 'PoorRate': 0.017, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：57773460021
# Name：联想（Lenovo）小新Air14锐龙版R7笔记本电脑超薄本超级本学生用轻薄女生商务办公游戏超极本 标配丨锐龙7 8GB内存 512G固态 荣耀银 2019
# Price：3799.00元
# Comment#： 2.1万+
# Good Ratio：98
#
# {'CommentsCount': [{'SkuId': 100009083152, 'ProductId': 100009083152, 'ShowCount': 1971, 'ShowCountStr': '1900+', 'CommentCountStr': '1.6万+', 'CommentCount': 16342, 'AverageScore': 5, 'DefaultGoodCountStr': '1.2万+', 'DefaultGoodCount': 12173, 'GoodCountStr': '3900+', 'GoodCount': 3939, 'AfterCount': 195, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 217, 'VideoCountStr': '200+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '90+', 'GeneralCount': 92, 'GeneralRate': 0.022, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '100+', 'PoorCount': 138, 'SensitiveBook': 0, 'PoorRate': 0.038, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：100009083152
# Name：京品电脑联想(Lenovo)  Y9000X英特尔酷睿i7 15.6英寸高性能标压轻薄笔记本电脑(i7-9750H 16G 1TSSD FHD)深空灰
# Price：8699.00元
# Comment#： 1.6万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100007288862, 'ProductId': 100007288862, 'ShowCount': 25705, 'ShowCountStr': '2.5万+', 'CommentCountStr': '33万+', 'CommentCount': 336678, 'AverageScore': 5, 'DefaultGoodCountStr': '24万+', 'DefaultGoodCount': 243077, 'GoodCountStr': '9.1万+', 'GoodCount': 91752, 'AfterCount': 4407, 'OneYear': 0, 'AfterCountStr': '4400+', 'VideoCount': 3354, 'VideoCountStr': '3300+', 'GoodRate': 0.96, 'GoodRateShow': 96, 'GoodRateStyle': 144, 'GeneralCountStr': '1600+', 'GeneralCount': 1671, 'GeneralRate': 0.017, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '2100+', 'PoorCount': 2131, 'SensitiveBook': 0, 'PoorRate': 0.023, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：100007288862
# Name：京品电脑联想(Lenovo)拯救者Y7000P 2019英特尔酷睿i7 15.6英寸游戏笔记本电脑(i7-9750H 16G 1TSSD GTX1650 144Hz)
# Price：8299.00元
# Comment#： 33万+
# Good Ratio：96
#
# {'CommentsCount': [{'SkuId': 100005724690, 'ProductId': 100005724690, 'ShowCount': 25705, 'ShowCountStr': '2.5万+', 'CommentCountStr': '33万+', 'CommentCount': 336678, 'AverageScore': 5, 'DefaultGoodCountStr': '24万+', 'DefaultGoodCount': 243077, 'GoodCountStr': '9.1万+', 'GoodCount': 91752, 'AfterCount': 4407, 'OneYear': 0, 'AfterCountStr': '4400+', 'VideoCount': 3354, 'VideoCountStr': '3300+', 'GoodRate': 0.96, 'GoodRateShow': 96, 'GoodRateStyle': 144, 'GeneralCountStr': '1600+', 'GeneralCount': 1671, 'GeneralRate': 0.017, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '2100+', 'PoorCount': 2131, 'SensitiveBook': 0, 'PoorRate': 0.023, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：100005724690
# Name：京品电脑联想(Lenovo)拯救者Y7000 2019英特尔酷睿i5 15.6英寸游戏笔记本电脑(i5-9300H 8G 512G SSD GTX1050 3G IPS)
# Price：5699.00元
# Comment#： 33万+
# Good Ratio：96
#
# {'CommentsCount': [{'SkuId': 100006581268, 'ProductId': 100006581268, 'ShowCount': 2822, 'ShowCountStr': '2800+', 'CommentCountStr': '10万+', 'CommentCount': 107841, 'AverageScore': 5, 'DefaultGoodCountStr': '8.5万+', 'DefaultGoodCount': 85766, 'GoodCountStr': '3.7万+', 'GoodCount': 37015, 'AfterCount': 651, 'OneYear': 0, 'AfterCountStr': '600+', 'VideoCount': 374, 'VideoCountStr': '300+', 'GoodRate': 0.97, 'GoodRateShow': 97, 'GoodRateStyle': 145, 'GeneralCountStr': '200+', 'GeneralCount': 278, 'GeneralRate': 0.007, 'GeneralRateShow': 1, 'GeneralRateStyle': 1, 'PoorCountStr': '600+', 'PoorCount': 616, 'SensitiveBook': 0, 'PoorRate': 0.023, 'PoorRateShow': 2, 'PoorRateStyle': 4}]}
# ID：100006581268
# Name：联想（Lenovo）天逸510S 英特尔酷睿i5 个人商务台式电脑整机（I5-9400 8G 1T WiFi Win10 ）21.5英寸
# Price：3799.00元
# Comment#： 10万+
# Good Ratio：97
#
# {'CommentsCount': [{'SkuId': 100002845047, 'ProductId': 100002845047, 'ShowCount': 465, 'ShowCountStr': '400+', 'CommentCountStr': '1.2万+', 'CommentCount': 12679, 'AverageScore': 5, 'DefaultGoodCountStr': '9700+', 'DefaultGoodCount': 9768, 'GoodCountStr': '2700+', 'GoodCount': 2763, 'AfterCount': 106, 'OneYear': 0, 'AfterCountStr': '100+', 'VideoCount': 89, 'VideoCountStr': '80+', 'GoodRate': 0.94, 'GoodRateShow': 94, 'GoodRateStyle': 141, 'GeneralCountStr': '50+', 'GeneralCount': 55, 'GeneralRate': 0.018, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '90+', 'PoorCount': 93, 'SensitiveBook': 0, 'PoorRate': 0.042, 'PoorRateShow': 4, 'PoorRateStyle': 6}]}
# ID：100002845047
# Name：京品电脑联想(Lenovo)小新14英寸 英特尔酷睿i5 轻薄窄边框笔记本电脑(I5-8265U 8G  256G PCIe )渣渣灰
# Price：3799.00元
# Comment#： 1.2万+
# Good Ratio：94
#
# {'CommentsCount': [{'SkuId': 100003150685, 'ProductId': 100003150685, 'ShowCount': 25705, 'ShowCountStr': '2.5万+', 'CommentCountStr': '33万+', 'CommentCount': 336673, 'AverageScore': 5, 'DefaultGoodCountStr': '24万+', 'DefaultGoodCount': 243077, 'GoodCountStr': '9.1万+', 'GoodCount': 91748, 'AfterCount': 4407, 'OneYear': 0, 'AfterCountStr': '4400+', 'VideoCount': 3354, 'VideoCountStr': '3300+', 'GoodRate': 0.96, 'GoodRateShow': 96, 'GoodRateStyle': 144, 'GeneralCountStr': '1600+', 'GeneralCount': 1671, 'GeneralRate': 0.017, 'GeneralRateShow': 2, 'GeneralRateStyle': 3, 'PoorCountStr': '2100+', 'PoorCount': 2130, 'SensitiveBook': 0, 'PoorRate': 0.023, 'PoorRateShow': 2, 'PoorRateStyle': 3}]}
# ID：100003150685
# Name：京品电脑联想(Lenovo)拯救者Y7000 2019英特尔酷睿i715.6英寸游戏笔记本电脑(i7-9750H 8G 1T SSD GTX1650 72%NTSC)
# Price：7599.00元
# Comment#： 33万+
# Good Ratio：96
#
# {'CommentsCount': [{'SkuId': 1337248, 'ProductId': 1337248, 'ShowCount': 30070, 'ShowCountStr': '3万+', 'CommentCountStr': '82万+', 'CommentCount': 826460, 'AverageScore': 5, 'DefaultGoodCountStr': '57万+', 'DefaultGoodCount': 572498, 'GoodCountStr': '57万+', 'GoodCount': 577347, 'AfterCount': 3349, 'OneYear': 0, 'AfterCountStr': '3300+', 'VideoCount': 1241, 'VideoCountStr': '1200+', 'GoodRate': 0.99, 'GoodRateShow': 99, 'GoodRateStyle': 148, 'GeneralCountStr': '2600+', 'GeneralCount': 2635, 'GeneralRate': 0.008, 'GeneralRateShow': 1, 'GeneralRateStyle': 2, 'PoorCountStr': '1400+', 'PoorCount': 1447, 'SensitiveBook': 0, 'PoorRate': 0.002, 'PoorRateShow': 0, 'PoorRateStyle': 0}]}
# ID：1337248
# Name：联想（Lenovo）鼠标有线鼠标 办公鼠标 联想大红点M120Pro有线鼠标 笔记本台式机鼠标 京东自营
# Price：29.00元
# Comment#： 82万+
# Good Ratio：99
#
# {'CommentsCount': [{'SkuId': 100003335145, 'ProductId': 100003335145, 'ShowCount': 966, 'ShowCountStr': '900+', 'CommentCountStr': '2.1万+', 'CommentCount': 21604, 'AverageScore': 5, 'DefaultGoodCountStr': '1.6万+', 'DefaultGoodCount': 16414, 'GoodCountStr': '4800+', 'GoodCount': 4815, 'AfterCount': 311, 'OneYear': 0, 'AfterCountStr': '300+', 'VideoCount': 157, 'VideoCountStr': '100+', 'GoodRate': 0.92, 'GoodRateShow': 92, 'GoodRateStyle': 138, 'GeneralCountStr': '100+', 'GeneralCount': 145, 'GeneralRate': 0.027, 'GeneralRateShow': 3, 'GeneralRateStyle': 4, 'PoorCountStr': '200+', 'PoorCount': 230, 'SensitiveBook': 0, 'PoorRate': 0.053, 'PoorRateShow': 5, 'PoorRateStyle': 8}]}
# ID：100003335145
# Name：京品电脑联想（Lenovo）威6 Pro 英特尔酷睿 i5 13.3英寸轻薄窄边框笔记本电脑(i5-8265U 8G 512GSSD 2G独显 100%sRGB 一键开机登录 Type-C 两年上门)太空灰
# Price：4699.00元
# Comment#： 2.1万+
# Good Ratio：92
